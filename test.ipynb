# %%
import datetime as dt
import src.db as db

battles = db.load_battles(date_from=dt.date(2023, 3, 1), date_to=dt.date(2023, 3, 31))
battles["mode"].value_counts()
# Out:
# area      13304
# yagura     9463
# hoko       9208
# asari      7020
# Name: mode, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()
sns.displot(
    data=battles,
    x="power",
    hue="mode",
    multiple="stack",
)
plt.show()
